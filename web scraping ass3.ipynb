# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\lokes\appdata\roaming\python\python38\site-packages (4.1.0)
# Requirement already satisfied: trio~=0.17 in c:\users\lokes\appdata\roaming\python\python38\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\nams1\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\lokes\appdata\roaming\python\python38\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sniffio in c:\users\nams1\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\lokes\appdata\roaming\python\python38\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\nams1\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: idna in c:\users\nams1\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: async-generator>=1.9 in c:\users\nams1\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\nams1\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\nams1\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\nams1\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\lokes\appdata\roaming\python\python38\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\nams1\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\nams1\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: certifi in c:\users\nams1\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: six>=1.5.2 in c:\users\nams1\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\lokes\appdata\roaming\python\python38\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import selenium
from selenium import webdriver
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# 1.Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user.
#
# 2.In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a dataframe and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
driver.get('https://www.amazon.in')

# %%
time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Guitar

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=3
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

#Make empty lists
Brand = []   
Name = []
Rating = []
no_of_ratings = []
Price = []
Return = []
expected_delivery = []
Availability = [] 
Other_Details = []

for url in product_urls:
    driver.get(url)
     
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')      
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')    


    time.sleep(1)
    # Extracting name from id
    try:
        name = driver.find_element_by_id('productTitle')      
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-')


    time.sleep(1)    
    # Extracting Ratings from xpath    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    # Extracting No of Ratings from xpath
    try:
        no_rating = driver.find_element_by_id('acrCustomerReviewText')  
        no_of_ratings.append(no_rating.text)
    except NoSuchElementException:
        no_of_ratings.append('-')


    time.sleep(1)
    # Extracting price from xpath    
    try:
        price = driver.find_element_by_xpath('//td[@class="a-span12"]')  
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')


    time.sleep(1)
    # Extracting Return from xpath
    try:
        return_ = driver.find_element_by_xpath('//a[@class="a-size-small a-link-normal a-text-normal"]')  
        Return.append(return_.text)
    except NoSuchElementException:
        Return.append('-')


    time.sleep(1)
    # Extracting expected_delivery from xpath
    try:
        exptd_dlvry= driver.find_element_by_xpath('//span[@class="a-color-error"]')  
        expected_delivery.append(exptd_dlvry.text)
    except NoSuchElementException:
         expected_delivery.append('-')
    time.sleep(1)
    # Extracting Availability from xpath         
    try:
        avl= driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')  
        Availability.append(avl.text)
    except NoSuchElementException:
        Availability.append('-')



    time.sleep(1)
    # Extracting Other Details from xpath    
    try:
        othr_dtls= driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')  
        Other_Details.append(othr_dtls.text)
    except NoSuchElementException:
        Other_Details.append('-')

time.sleep(2)    
# Make dataframe
prod_df = pd.DataFrame({'Brand':Brand,'Name':Name,'Rating':Rating,'No. of ratings':no_of_ratings,'Price':Price,
                        'Return/Exchange':Return,'Expected Delivery':expected_delivery,'Availability':Availability,
                        'Other Details':Other_Details,'URL':product_urls})
prod_df.head(5)

# %% [markdown]
# 3.. Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %% [markdown]
# fruits

# %%
driver.get("https://images.google.com/")

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')
search_bar.send_keys("fruits")       
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')
search_button.click()

# %%
Fruits=[]
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
        Fruits.append(i.get_attribute('src'))
        
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
    Fruits.append(i.get_attribute('data-src'))

# %% [raw]
# Cars

# %%
driver.get("https://images.google.com/")

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')
search_bar.send_keys("Cars")
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')
search_button.click()

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')   
search_bar.send_keys("Machine Learning") 
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')

# %%
Machine_Learning=[]
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
        Machine_Learning.append(i.get_attribute('src'))
        
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
    Machine_Learning.append(i.get_attribute('data-src'))

# %% [markdown]
# Guitar

# %%
driver.get("https://images.google.com/")

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')   
search_bar.send_keys("Guitar") 
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')   
search_button.click()

# %%
Guitar=[]
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
        Guitar.append(i.get_attribute('src'))
        
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
    Guitar.append(i.get_attribute('data-src'))

# %%
driver.get("https://images.google.com/")

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')   
search_bar.send_keys("Cakes") 
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')   
search_button.click()

# %%
Cakes=[]
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
        Cakes.append(i.get_attribute('src'))
        
for i in driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']"):
    Cakes.append(i.get_attribute('data-src'))

# %%
Images=pd.DataFrame({})
Images['Fruit_Images']=Fruits[:90]
Images['Car_Images']=Cars[:90]
Images['Machine_Learning_Images']=Machine_Learning[:90]
Images['Guitar_Images']=Guitar[:90]
Images['Cakes_Images']=Cakes[:90]
Images
# Out:
#                                          Fruit_Images  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 85  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 86  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 87  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 88  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 89  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                            Car_Images  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 85  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 86  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 87  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 88  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 89  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                               Machine_Learning_Images  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 85  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 86  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 87  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 88  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 89  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                         Guitar_Images  \
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 85  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 86  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 87  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 88  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 89  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                          Cakes_Images
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 85  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 86  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 87  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 88  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 89  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [90 rows x 5 columns]

# %% [markdown]
# 4.Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. In case if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver.get('https://www.flipkart.com/')

# %%
prod = input(" Enter the name of the mobile phone you want to search : ")
# Out:
#  Enter the name of the mobile phone you want to search : i phone

# %%
url = 'https://www.flipkart.com/'
driver.get(url)

# %%
import time

# %%
search_bar = driver.find_element_by_xpath('//div[@class="_3OO5Xc"]/input')    

search_bar.send_keys(prod)
search_button = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')  
search_button.click()
time.sleep(5)

# %%
flip_urls = []
urls = driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')
for url in urls:
    flip_urls.append(url.get_attribute("href"))

# %%
brand=[]
smart_phone=[]
colour=[]
RAM=[]
ROM=[]
primary_camera=[]
secondary_camera=[]
display_size=[]
display_resolution=[]
processor=[]
processor_cores=[]
battery=[]
battery_type=[]
price=[]
URL=[]

# %%
for url in flip_urls:
    driver.get(url)                                                        

    URL.append(url)                                     
    
    
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')  
        read_more.click()
    except NoSuchElementException:
        print("Exception Occured. Moving to next page")
    
    try:
        Brand = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      
        brand.append(Brand.text.split()[0])
    except NoSuchElementException:
        brand.append('-')
        
    try:
        smart_phone.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[1]/table/tbody/tr[3]/td[2]').text)
    except:
        smart_phone.append('-')
        
   
    try:
        Colour = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      
        colour.append(Colour.text)
    except NoSuchElementException:
        colour.append('-')
        
    try:
        Price = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')      
        price.append(Price.text)
    except NoSuchElementException:
        price.append('-')
    try:
        RAM.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[4]/table/tbody/tr[2]/td[2]').text)
    except:
        RAM.append('-')
    try:
        ROM.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[4]/table/tbody/tr[1]/td[2]').text)
    except:
        ROM.append('-')
    try:
        primary_camera.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[5]/table/tbody/tr[2]/td[2]').text)
    except:
        primary_camera.append('-')
    try:
        secondary_camera.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[5]/table/tbody/tr[5]/td[2]').text)
    except:
        secondary_camera.append('-')
    try:
        display_size.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[2]/table/tbody/tr[1]/td[2]').text)
    except:
        display_size.append('-')
    try:
        display_resolution.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[2]/table/tbody/tr[2]/td[2]').text)
    except:
        display_resolution.append('-')
        
    try:
        processor.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[3]/table/tbody/tr[2]/td[2]').text)
    except:
        processor.append('-')
    try:
        processor_cores.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[3]/table/tbody/tr[3]/td[2]').text)
    except:
        processor_cores.append('-')
    try:
        battery.append(driver.find_element_by_xpath('//div[@class="_1UhVsV"]/div[10]/table/tbody/tr[1]/td[2]').text)
    except:
        battery.append('-')

# %%
df=pd.DataFrame({})
df['brand']=brand
df['smart_phone']=smart_phone
df['colour']=colour
df['RAM']=RAM
df['ROM']=ROM
df['primary_camera']=primary_camera
df['secondary_camera']=secondary_camera
df['display_size']=display_size
df['display_resolution']=display_resolution
df['processor']=processor
df['processor_cores']=processor_cores
df['battery_type']=battery
df['price']=price
df['URL']=URL
df[:24]
# Out:
#     brand     smart_phone        colour  \
# 0   APPLE               -             -
# 1   APPLE               -             -
# 2   APPLE               -             -
# 3   APPLE               -             -
# 4   APPLE  iPhone 12 Mini         Black
# 5   APPLE               -             -
# 6   APPLE               -             -
# 7   APPLE       iPhone 12         Black
# 8   APPLE  iPhone 12 Mini          Blue
# 9   APPLE  iPhone 12 Mini         White
# 10  APPLE               -             -
# 11  Apple       iPhone XR  (PRODUCT)RED
# 12  APPLE               -             -
# 13  APPLE               -             -
# 14  APPLE       iPhone 13      Midnight
# 15  APPLE               -             -
# 16  APPLE               -             -
# 17  APPLE               -             -
# 18  APPLE  iPhone 12 Mini        Purple
# 19  APPLE               -             -
# 20  APPLE               -             -
# 21  APPLE       iPhone 13      Midnight
# 22  APPLE       iPhone 13  (PRODUCT)RED
# 23  APPLE               -             -
#
#                                            RAM       ROM    primary_camera  \
# 0   A13 Bionic Chip with 3rd Gen Neural Engine  iOS 14.2                 -
# 1   A13 Bionic Chip with 3rd Gen Neural Engine  iOS 14.2                 -
# 2   A13 Bionic Chip with 3rd Gen Neural Engine  iOS 14.2                 -
# 3   A13 Bionic Chip with 3rd Gen Neural Engine  iOS 14.2                 -
# 4                                            -     64 GB       12MP + 12MP
# 5   A13 Bionic Chip with 3rd Gen Neural Engine  iOS 14.2                 -
# 6   A13 Bionic Chip with 3rd Gen Neural Engine  iOS 14.2                 -
# 7                                            -     64 GB       12MP + 12MP
# 8                                            -     64 GB       12MP + 12MP
# 9                                            -     64 GB       12MP + 12MP
# 10                             A13 Bionic Chip  iOS 14.2                 -
# 11                                           -     64 GB  12MP Rear Camera
# 12                             A13 Bionic Chip  iOS 14.2                 -
# 13                             A13 Bionic Chip  iOS 14.2                 -
# 14                                           -    256 GB       12MP + 12MP
# 15                             A13 Bionic Chip  iOS 14.2                 -
# 16                             A13 Bionic Chip  iOS 14.2                 -
# 17  A13 Bionic Chip with 3rd Gen Neural Engine  iOS 14.2                 -
# 18                                           -     64 GB       12MP + 12MP
# 19                             A12 Bionic Chip  iOS 14.2                 -
# 20                             A12 Bionic Chip  iOS 14.2                 -
# 21                                           -    128 GB       12MP + 12MP
# 22                                           -    256 GB       12MP + 12MP
# 23                             A13 Bionic Chip  iOS 14.2                 -
#
#      secondary_camera                                     display_size  \
# 0                   -  iPhone, USB-C to Lightning Cable, Documentation
# 1                   -  iPhone, USB-C to Lightning Cable, Documentation
# 2                   -  iPhone, USB-C to Lightning Cable, Documentation
# 3                   -  iPhone, USB-C to Lightning Cable, Documentation
# 4   12MP Front Camera                              13.72 cm (5.4 inch)
# 5                   -  iPhone, USB-C to Lightning Cable, Documentation
# 6                   -  iPhone, USB-C to Lightning Cable, Documentation
# 7   12MP Front Camera                              15.49 cm (6.1 inch)
# 8   12MP Front Camera                              13.72 cm (5.4 inch)
# 9   12MP Front Camera                              13.72 cm (5.4 inch)
# 10                  -  iPhone, USB-C to Lightning Cable, Documentation
# 11   7MP Front Camera                              15.49 cm (6.1 inch)
# 12                  -  iPhone, USB-C to Lightning Cable, Documentation
# 13                  -  iPhone, USB-C to Lightning Cable, Documentation
# 14  12MP Front Camera                              15.49 cm (6.1 inch)
# 15                  -  iPhone, USB-C to Lightning Cable, Documentation
# 16                  -  iPhone, USB-C to Lightning Cable, Documentation
# 17                  -  iPhone, USB-C to Lightning Cable, Documentation
# 18  12MP Front Camera                              13.72 cm (5.4 inch)
# 19                  -  iPhone, USB-C to Lightning Cable, Documentation
# 20                  -  iPhone, USB-C to Lightning Cable, Documentation
# 21  12MP Front Camera                              15.49 cm (6.1 inch)
# 22  12MP Front Camera                              15.49 cm (6.1 inch)
# 23                  -  iPhone, USB-C to Lightning Cable, Documentation
#
#     display_resolution                                          processor  \
# 0            MHGQ3HN/A                                  1334 x 750 Pixels
# 1            MHGP3HN/A                                  1334 x 750 Pixels
# 2            MHGR3HN/A                                  1334 x 750 Pixels
# 3            MHGV3HN/A                                  1334 x 750 Pixels
# 4   2340 x 1080 Pixels  A14 Bionic Chip with Next Generation Neural En...
# 5            MHGU3HN/A                                  1334 x 750 Pixels
# 6            MHGT3HN/A                                  1334 x 750 Pixels
# 7   2532 x 1170 Pixels  A14 Bionic Chip with Next Generation Neural En...
# 8   2340 x 1080 Pixels  A14 Bionic Chip with Next Generation Neural En...
# 9   2340 x 1080 Pixels  A14 Bionic Chip with Next Generation Neural En...
# 10           MHDA3HN/A                                  1792 x 828 Pixels
# 11   1792 x 828 pixels                                    A12 Bionic Chip
# 12           MHDH3HN/A                                  1792 x 828 Pixels
# 13           MHDM3HN/A                                  1792 x 828 Pixels
# 14  2532 x 1170 Pixels                                    A15 Bionic Chip
# 15           MHDJ3HN/A                                  1792 x 828 Pixels
# 16           MHDK3HN/A                                  1792 x 828 Pixels
# 17           MHGY3HN/A                                  1334 x 750 Pixels
# 18  2340 x 1080 Pixels  A14 Bionic Chip with Next Generation Neural En...
# 19           MH7N3HN/A                                  1792 x 828 Pixels
# 20           MH7M3HN/A                                  1792 x 828 Pixels
# 21  2532 x 1170 Pixels                                    A15 Bionic Chip
# 22  2532 x 1170 Pixels                                    A15 Bionic Chip
# 23           MHDD3HN/A                                  1792 x 828 Pixels
#
#                                       processor_cores  \
# 0                                   Retina HD Display
# 1                                   Retina HD Display
# 2                                   Retina HD Display
# 3                                   Retina HD Display
# 4                                                   -
# 5                                   Retina HD Display
# 6                                   Retina HD Display
# 7                                                   -
# 8                                                   -
# 9                                                   -
# 10                           Liquid Retina HD Display
# 11                                                  -
# 12                           Liquid Retina HD Display
# 13                           Liquid Retina HD Display
# 14                                          Hexa Core
# 15                           Liquid Retina HD Display
# 16                           Liquid Retina HD Display
# 17                                  Retina HD Display
# 18                                                  -
# 19  Apple-designed GPU - 4-core, Graphics Performa...
# 20  Apple-designed GPU - 4-core, Graphics Performa...
# 21                                          Hexa Core
# 22                                          Hexa Core
# 23                           Liquid Retina HD Display
#
#                                          battery_type    price  \
# 0   AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹30,299
# 1   AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹30,299
# 2   AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹30,299
# 3   AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹35,099
# 4                                             64.2 mm  ₹49,999
# 5   AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹35,099
# 6   AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹35,099
# 7                                             71.5 mm  ₹60,299
# 8                                             64.2 mm  ₹49,999
# 9                                             64.2 mm  ₹49,999
# 10  AAC LC, HE AAC, HE AAC v2, Protected AAC, MP3,...  ₹49,900
# 11                                            75.7 mm  ₹39,999
# 12  AAC LC, HE AAC, HE AAC v2, Protected AAC, MP3,...  ₹54,900
# 13  AAC LC, HE AAC, HE AAC v2, Protected AAC, MP3,...  ₹54,900
# 14                                            71.5 mm  ₹84,900
# 15  AAC LC, HE AAC, HE AAC v2, Protected AAC, MP3,...  ₹54,900
# 16  AAC LC, HE AAC, HE AAC v2, Protected AAC, MP3,...  ₹54,900
# 17  AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹44,999
# 18                                            64.2 mm  ₹49,999
# 19  AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹44,999
# 20  AAC-LC, HE-AAC, HE-AAC v2, Protected AAC, MP3,...  ₹44,999
# 21                                            71.5 mm  ₹74,900
# 22                                            71.5 mm  ₹84,900
# 23  AAC LC, HE AAC, HE AAC v2, Protected AAC, MP3,...  ₹49,900
#
#                                                   URL
# 0   https://www.flipkart.com/apple-iphone-se-white...
# 1   https://www.flipkart.com/apple-iphone-se-black...
# 2   https://www.flipkart.com/apple-iphone-se-red-6...
# 3   https://www.flipkart.com/apple-iphone-se-red-1...
# 4   https://www.flipkart.com/apple-iphone-12-mini-...
# 5   https://www.flipkart.com/apple-iphone-se-white...
# 6   https://www.flipkart.com/apple-iphone-se-black...
# 7   https://www.flipkart.com/apple-iphone-12-black...
# 8   https://www.flipkart.com/apple-iphone-12-mini-...
# 9   https://www.flipkart.com/apple-iphone-12-mini-...
# 10  https://www.flipkart.com/apple-iphone-11-black...
# 11  https://www.flipkart.com/apple-iphone-xr-produ...
# 12  https://www.flipkart.com/apple-iphone-11-black...
# 13  https://www.flipkart.com/apple-iphone-11-purpl...
# 14  https://www.flipkart.com/apple-iphone-13-midni...
# 15  https://www.flipkart.com/apple-iphone-11-white...
# 16  https://www.flipkart.com/apple-iphone-11-red-1...
# 17  https://www.flipkart.com/apple-iphone-se-red-2...
# 18  https://www.flipkart.com/apple-iphone-12-mini-...
# 19  https://www.flipkart.com/apple-iphone-xr-produ...
# 20  https://www.flipkart.com/apple-iphone-xr-white...
# 21  https://www.flipkart.com/apple-iphone-13-midni...
# 22  https://www.flipkart.com/apple-iphone-13-produ...
# 23  https://www.flipkart.com/apple-iphone-11-red-6...

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver.get("https://www.google.co.in/maps")

# %%
city = input('Enter City Name : ')
# Out:
# Enter City Name : Betul

# %%
search = driver.find_element_by_id("searchboxinput")                      
search.clear()                                                            
search.send_keys(city)                                                     
button = driver.find_element_by_id("searchbox-searchbutton")              
button.click()

# %%
import regex as re

# %%
try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/Betul,+Madhya+Pradesh+460001/@21.9069912,77.8653602,13z/data=!3m1!4b1!4m5!3m4!1s0x3bd6099355fd39f5:0xfcd7f3a44fc36322!8m2!3d21.9011601!4d77.8960201
# Latitude = 21.9069912, Longitude = 77.8653602

# %% [markdown]
# 6.Write a program to scrap details of all the funding deals for second quarter (i.e. Jan 21 – March 21) from trak.in.

# %%
driver.get('https://trak.in/')

# %%
l1 = driver.find_element_by_xpath("//li[@id='menu-item-51510']/a").get_attribute('href')
driver.get(l1)

# %%
url_string = driver.current_url
print("The Current URL: ", url_string)
# Out:
# The Current URL:  https://trak.in/india-startup-funding-investment-2015/

# %%
date=[]
startup_name=[]
Industry_Vertical=[]
sub_vertical=[]
location=[]
investor=[]
investment_type=[]
amount_in_usd=[]

# %%
for i in range(48,51):
    driver.find_element_by_xpath('//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(i)).click()
    
    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        date.append(d.text)

    
    sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        startup_name.append(n.text)
    
    
    ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        Industry_Vertical.append(n.text)
    
    
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        sub_vertical.append(s.text)

    
    loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        location.append(l.text)
    
    
    inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        investor.append(n.text)
    
    
    invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        investment_type.append(n.text)
    amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        amount_in_usd.append(a.text)

# %%
df=pd.DataFrame({})
df['startup_name']=startup_name
df['Industry_Vertical']=Industry_Vertical
df['sub_vertical']=sub_vertical
df['location']=location
df['investor']=investor
df['investment_type']=investment_type
df['amount_in_usd']=amount_in_usd
df
# Out:
#                  startup_name                       Industry_Vertical  \
# 0                    Flipkart                              E-commerce
# 1                     Vedantu                                 EduTech
# 2                        Crio                                 EduTech
# 3                     goDutch                                 FinTech
# 4                    Mystifly                     Airfare Marketplace
# 5                JetSynthesys                Gaming and Entertainment
# 6                    gigIndia                             Marketplace
# 7                   PumPumPum                       Automotive Rental
# 8                        FLYX                              OTT Player
# 9   Open Appliances Pvt. Ltd.                  Information Technology
# 10                     Practo                              HealthTech
# 11                    Medlife                              E-commerce
# 12                  HungerBox                                FoodTech
# 13                      Dunzo                   Hyper-local Logistics
# 14                   Terra.do                                 EduTech
# 15                  Classplus                                 EduTech
# 16                       Niyo                                 FinTech
# 17                  ZestMoney                                 FinTech
# 18                FreshToHome                              E-commerce
# 19                    Eduvanz                                 FinTech
# 20                 CrowdPouch                                 FinTech
# 21                 DrinkPrime                      Water Purification
# 22                     Byju’s                                 EduTech
# 23                  mCaffeine                           Personal Care
# 24                     Qshala                                 EduTech
# 25                      Winzo                           Online Gaming
# 26                Hippo Video  Video Customer Experience(CX) Platform
# 27                    Melorra                              E-commerce
# 28                        1mg                              E-commerce
# 29                      mfine                              HealthTech
# 30                       Apna                         Human Resources
# 31                    Railofy                          Transportation
# 32            Cell Propulsion                              Automobile
#
#                                          sub_vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                 Financial Services
# 21                                 Water Purification
# 22                                    Online Tutoring
# 23                                Skincare & Haircare
# 24                 Online Curiosity Platform for Kids
# 25                                      Online Gaming
# 26             Video Customer Experience(CX) Platform
# 27                               Online Jewelry Store
# 28                                    Online Pharmacy
# 29                      On-Demand Healthcare Services
# 30                               Recruitment Platform
# 31                       WL & RAC protection platform
# 32                        Electric Mobility Solutions
#
#                                       location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                   Bangalore
# 22                                   Bangalore
# 23                                      Mumbai
# 24                                   Bangalore
# 25                                   New Delhi
# 26  Newark, Delaware, United States of Amercia
# 27                                   Bangalore
# 28                                     Gurgaon
# 29                                   Bangalore
# 30                                   Bangalore
# 31                                      Mumbai
# 32                                   Bangalore
#
#                                              investor         investment_type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20                         Elina Investments Pvt. Ltd                   Angel
# 21                        Sequoia Surge, ON Mauritius            Pre-Series A
# 22  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 23  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 24                                 Rainmatter Capital                   Angel
# 25  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 26  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 27                         Shadow Holdings, Lightbox.          Debt Financing
# 28         Gaja Capital, Tata Capital, Partners Group             In Progress
# 29                                   Caretech Pte Inc                Series B
# 30         Lightspeed India and Sequoia Capital India                Series A
# 31                                  Chiratae Ventures                    Seed
# 32                         growX Ventures and Micelio            pre-Series A
#
#       amount_in_usd
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20               NA
# 21        2,880,000
# 22      500,000,000
# 23        3,000,000
# 24          370,000
# 25       15,500,000
# 26        4,500,000
# 27   upto 8,900,000
# 28      100,000,000
# 29        5,400,000
# 30        8,000,000
# 31          950,000
# 32               NA

# %% [markdown]
# 7.Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
import requests

# %%
page = requests.get("https://www.digit.in/")
page
# Out:
# <Response [200]>

# %%
url = "https://www.digit.in/top-products/best-gaming-laptops-40.html"

# %%
driver.get(url)

# %%
name = []
price = []
OS = []
display = []
processor = []
weight = []
dimension = []
GPU = []

# %%
names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in names:
    name.append(i.text)
    
os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
for i in os:
    OS.append(i.text)
    
displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
for i in displays:
    display.append(i.text)
    
processors=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[3]/div/div")
for i in processors:
    processor.append(i.text)
processor

weights=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")
weight_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")
for i in range(len(weights)):
        if weights[i].text=='Weight':
            weight.append(weight_spec[i].text)
        
dimension=[]
dims=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")
dims_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")
for i in range(len(dims)):
        if dims[i].text=='Dimension':
            dimension.append(dims_spec[i].text)

GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")
GPUs_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")
for i in range(len(GPUs)):
     if GPUs[i].text=='Graphics Processor':
            GPU.append(GPUs_spec[i].text)
        
full_specs=[]
urls=driver.find_elements_by_xpath("//div[@class='full-specs']/span")
for i in urls:
    if i.get_attribute('data-href'):
        full_specs.append(i.get_attribute('data-href'))
    
for i in full_specs:
    driver.get(i)
    try:
        prices=driver.find_element_by_xpath("//div[@class='Block-price']/b")
        price.append(prices.text)
    except NoSuchElementException:
        price.append("No details available")

# %%
print(len(name),len(price),len(OS),len(display),len(processor),len(weight),len(dimension),len(GPU))
# Out:
# 10 10 10 10 0 10 10 10

# %%
prdct
# Out:
#                           Name                 Price               OS  \
# 0                 ACER NITRO 5  No details available       WINDOWS 10
# 1              MSI STEALTH 15M  No details available       WINDOWS 10
# 2       ASUS ROG STRIX SCAR 15  No details available       WINDOWS 10
# 3        ALIENWARE AREA 51M R2  No details available  WINDOWS 10 HOME
# 4             ALIENWARE M15 R3  No details available  WINDOWS 10 HOME
# 5       ASUS ROG STRIX SCAR 15  No details available  WINDOWS 10 HOME
# 6            ASUS ZEPHYRUS G14  No details available  WINDOWS 10 HOME
# 7             LENOVO LEGION 5I  No details available   WINDOWS 10 PRO
# 8     ASUS ROG ZEPHYRUS DUO 15  No details available       WINDOWS 10
# 9  ACER ASPIRE 7 GAMING LAPTOP  No details available  WINDOWS 10 HOME
#
#                Display
# 0  15.6" (1920 X 1080)
# 1  15.6" (1920 X 1080)
# 2  15.6" (2560 X 1440)
# 3  17.3" (1920 X 1080)
# 4  15.6" (3840 X 2160)
# 5  15.6" (1920 X 1080)
# 6    14" (1920 X 1080)
# 7  15.6" (1920 X 1080)
# 8  15.6" (3840 X 1100)
# 9  15.6" (1920 X 1080)

# %% [markdown]
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
import time

# %%
#driver=webdriver.Chrome('chromedriver',chrome_options=chrome_options)
#time.sleep(4)

url = 'https://www.forbes.com/billionaires/'
driver.get(url)
time.sleep(6)

# %%
rank=[]

for i in driver.find_elements_by_xpath('//div[@ class="rank"]'):

    rank.append(i.text.replace('\n',''))

Name=[]

for i in driver.find_elements_by_xpath('//div[@ class="personName"]'):

    Name.append(i.text.replace('\n',''))

Net_worth=[]

for i in driver.find_elements_by_xpath('//div[@ class="netWorth"]'):

    Net_worth.append(i.text.replace('\n',''))

Country=[]

for i in driver.find_elements_by_xpath('//div[@ class="countryOfCitizenship"]'):

    Country.append(i.text.replace('\n',''))

source=[]

for i in driver.find_elements_by_xpath('//div[@ class="source-column"]'):

    source.append(i.text.replace('\n',''))

Industry=[]

for i in driver.find_elements_by_xpath('//div[@ class="category"]'):

    Industry.append(i.text.replace('\n',''))

Age=[]

for i in driver.find_elements_by_xpath('//div[@ class="age"]'):

    Age.append(i.text.replace('\n',''))

# %%
import pandas as pd
billionaires=pd.DataFrame({})

billionaires['rank']=rank[:10]
billionaires['Name']=Name[:10]
billionaires['Net_worth']=Net_worth[:10]
billionaires['Industry']=Industry[:10]
billionaires['source']=source[:10]
billionaires['Country']=Country[:10]
billionaires['Age']=Age[:10]

# %%
billionaires
# Out:
#   rank                      Name Net_worth               Industry  \
# 0   1.                Jeff Bezos    $177 B             Technology
# 1   2.                 Elon Musk    $151 B             Automotive
# 2   3.  Bernard Arnault & family    $150 B       Fashion & Retail
# 3   4.                Bill Gates    $124 B             Technology
# 4   5.           Mark Zuckerberg     $97 B             Technology
# 5   6.            Warren Buffett     $96 B  Finance & Investments
# 6   7.             Larry Ellison     $93 B             Technology
# 7   8.                Larry Page   $91.5 B             Technology
# 8   9.               Sergey Brin     $89 B             Technology
# 9  10.             Mukesh Ambani   $84.5 B            Diversified
#
#                source        Country Age
# 0              Amazon  United States  57
# 1       Tesla, SpaceX  United States  49
# 2                LVMH         France  72
# 3           Microsoft  United States  65
# 4            Facebook  United States  36
# 5  Berkshire Hathaway  United States  90
# 6            software  United States  76
# 7              Google  United States  48
# 8              Google  United States  47
# 9         diversified          India  63

# %% [markdown]
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver.get('https://www.youtube.com/')
driver.implicitly_wait(10)

# %%
search_box=driver.find_element_by_xpath('//input[@ id="search"]')

# %%
search_box.send_keys("https://www.youtube.com/watch?v=X3paOmcrTjQ")

# %%
search_botton=driver.find_element_by_xpath('//button[@id="search-icon-legacy"]').click()

# %%
search_video=driver.find_element_by_xpath('//yt-formatted-string[@class="style-scope ytd-video-renderer"]').click()

# %%
comments=[]

for i in driver.find_elements_by_xpath('//yt-formatted-string[@class="count-texts.style-scope.ytd-comments-header-renderer"]'):

    comments.append(i.text.replace('\n',''))

# %%
import pandas as pd
youtube=pd.DataFrame({})



youtube['Comments']=comments[:500]

# %%
Timeof1update=[]
try:
    for i in  driver.find_elements_by_xpath('//div[@class="main.style-scope.ytd-comment-renderer"]'):
        if 'ago'in  i.text.strip():
            Timeof1update.append(i.text.replace('\n',''))
    
except NoSuchElementException :
    Timeof1update.append('-')

# %%
youtube['Timeof1update']=Timeof1update[:500]
youtube
# Out:
# Empty DataFrame
# Columns: [Comments, Timeof1update]
# Index: []

# %% [markdown]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
url = 'https://www.hostelworld.com/'
driver.get(url)
time.sleep(6)

# %%
search_Bar=driver.find_element_by_xpath('//*[@id="location-text-input-field"]')
search_Bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e4cbbef01948f30408bf04998f32540e", element="c89059b4-ebbc-474c-9421-c9241154adc0")>

# %%
search_Bar.send_keys('London, England')

# %%
search_Button=driver.find_element_by_xpath('//*[@id="search-button"]')

# %%
search_Button.click()
time.sleep(5)

# %%
hostel_name=[]

for i in driver.find_elements_by_xpath('//h2[@ class="title title-6"]/a'):

    hostel_name.append(i.text.replace('\n',''))

# %%
distance=[]

for i in driver.find_elements_by_xpath('//span[@ class="description"]'):

    distance.append(i.text.replace('\n',''))
ratings=[]

for i in driver.find_elements_by_xpath('//div[@ class="score orange big"]'):

    ratings.append(i.text.replace('\n',''))
total_reviews=[]

for i in driver.find_elements_by_xpath('//div[@ class="reviews"]'):
    total_reviews.append(i.text.replace('\n',''))
overall_reviews=[]

for i in driver.find_elements_by_xpath('//div[@ class="keyword"]/span'):

    overall_reviews.append(i.text.replace('\n',''))
privates_price=[]

for i in driver.find_elements_by_xpath('//div[@ class="price-col"]'):
     if  'Privates'   in i.text.strip():
        privates_price.append(i.text.replace('\n',''))
dorms_price=[]

for i in driver.find_elements_by_xpath('//div[@ class="price-col"]'):
     if  'Dorms'   in i.text.strip():
        dorms_price.append(i.text.replace('\n',''))
facilities=[]

for i in driver.find_elements_by_xpath('//span[@ class="label"]'):
     if  'Free'   in i.text.strip():
        facilities.append(i.text.replace('\n',''))
url=[]

for i in driver.find_elements_by_xpath('//h2[@class="title title-6"]/a'):
    url.append(i.get_attribute('href'))

# %%
property_description=[]
for i in url[:10]:
    driver.get(i)
    time.sleep(3)

    try:
        E=driver.find_element_by_xpath('//div[@style="-webkit-line-clamp:12;"]')
        property_description.append(E.text)
        
    
    except NoSuchElementException :
        property_description.append('-')

# %%
property_short_description=[]
for i in url[:10]:
    driver.get(i)
    time.sleep(3)

    try:
        E=driver.find_element_by_xpath('//div[@class="content collapse-content"]')
        property_short_description.append(E.text)
        
    
    except NoSuchElementException :
        property_short_description.append('-')

# %%
import pandas as pd
table=pd.DataFrame({})
table['hostel_name']=hostel_name[:10]
table['distance']=distance[:10]
table['ratings']=ratings[:10]
table['total_reviews']=total_reviews[:10]
table['overall_reviews']=overall_reviews[:10]
table['privates_price']=privates_price[:10]
table['dorms_price']=dorms_price[:10]
table['facilities']=facilities[:10]
table['property_short_description']=property_short_description[:10]
table
